# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
df= pd.read_csv('movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#DATA CLEANING

# %%
#Checking for missing data
missing_values= df.isnull().sum() # Counting them as well

# %%
missing_values
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget        int64
# gross         int64
# company       int16
# runtime     float64
# dtype: object

# %%
#Data type of Columns Changed
df['budget']=df['budget'].astype('int64')

df['gross']=df['gross'].astype('int64')

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980         0    8.4   927000.0      1795    2832
# 1     3929       6      1  1980         0    5.8    65000.0      1578    1158
# 2     3641       4      0  1980         0    8.7  1200000.0       757    1818
# 3      204       4      4  1980         0    7.7   221000.0       889    1413
# 4      732       6      4  1980         0    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       265    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       265    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       265    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       265    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       265    6.8     3700.0       746    1184
#
# ...

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980         0    8.4   927000.0      1795    2832
# 1     3929       6      1  1980         0    5.8    65000.0      1578    1158
# 2     3641       4      0  1980         0    8.7  1200000.0       757    1818
# 3      204       4      4  1980         0    7.7   221000.0       889    1413
# 4      732       6      4  1980         0    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       265    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       265    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       265    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       265    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       265    6.8     3700.0       746    1184
#
# ...

# %%
df.sort_values(by= 'gross',inplace=False, ascending= False)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       166    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       263    8.4   903000.0       105     513
# 3045  4909       5      6  1997        62    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       242    7.8   876000.0       768    1806
# 7244   389       5      0  2018       259    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       240    5.8     3500.0       585    2924
# 2434  2969       5      0  1993        54    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000        83    6.8    43000.0       952    1683
# 272   2909       6      9  1982         5    3.9     2300.0       261      55
# 3203  4966       5      4  1997        59    5.7     5800.0       651     161
#
# ...

# %%
#SEE ALL DATA SETS
#pd.set_option('display.max_rows', None)

# %%
#Dropping duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
#Checking for Correlations to the Gross Column

# %%
df.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget        int64
# gross         int64
# company       int16
# runtime     float64
# dtype: object

# %%
#in a a scatter plot
sns.scatterplot(data=df,x=df['budget'],y=df['gross'])
plt.title('Gross Earnings VS Budget SCATTERPLOT')
# Out:
# Text(0.5, 1.0, 'Gross Earnings VS Budget SCATTERPLOT')

# %%
plt.show()

# %%
sns.regplot(data=df,x=df['budget'],y=df['gross'],line_kws={'color':'blue'},scatter_kws={'color':'red'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
plt.show()

# %%
#We were able to identify the positive correlation for GROSS VS BUDGET

# %%
#We were also able to determine a HIGH CORRELATION between Budget and Gross

# %%
df.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget        int64
# gross         int64
# company       int16
# runtime     float64
# dtype: object

# %%
numbered_correlation
# Out:
#          budget      gross      votes  runtime  score
# 0      19000000   46998772   927000.0    146.0    8.4
# 1       4500000   58853106    65000.0    104.0    5.8
# 2      18000000  538375067  1200000.0    124.0    8.7
# 3       3500000   83453539   221000.0     88.0    7.7
# 4       6000000   39846344   108000.0     98.0    7.3
# ...         ...        ...        ...      ...    ...
# 7648   90000000  426505244   140000.0    124.0    6.6
# 7649   85000000  319715683   102000.0     99.0    6.5
# 7650  175000000  245487753    53000.0    101.0    5.6
# 7651  135000000  111105497    42000.0    100.0    6.8
# 7652   80000000  461421559     3700.0    149.0    6.8
#
# [5421 rows x 5 columns]

# %%
# Making all columns numerical 

for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name]= df[col_name].cat.codes

df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980         0    8.4   927000.0      1795    2832
# 1     3929       6      1  1980         0    5.8    65000.0      1578    1158
# 2     3641       4      0  1980         0    8.7  1200000.0       757    1818
# 3      204       4      4  1980         0    7.7   221000.0       889    1413
# 4      732       6      4  1980         0    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       265    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       265    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       265    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       265    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       265    6.8     3700.0       746    1184
#
# ...

# %%
df_num=df.corr()
plt.figure(figsize=(12,6))
sns.heatmap(df_num,annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %%
plt.show()

# %%
# Sorting to identify correlation quickly
df_num.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.130598 -0.011344 -0.089798 -0.087292 -0.135637
# rating   -0.130598  1.000000  0.345024 -0.161890 -0.149208 -0.005819
# genre    -0.011344  0.345024  1.000000 -0.314492 -0.299411 -0.110121
# year     -0.089798 -0.161890 -0.314492  1.000000  0.998624 -0.032617
# released -0.087292 -0.149208 -0.299411  0.998624  1.000000 -0.025276
# score    -0.135637 -0.005819 -0.110121 -0.032617 -0.025276  1.000000
# votes    -0.168410 -0.281216 -0.516452  0.253554  0.241969  0.632874
# director -0.063671 -0.037727 -0.006337 -0.274697 -0.272975 -0.187476
# writer   -0.064814 -0.059210  0.043574 -0.257871 -0.257747 -0.183851
# star     -0.093991 -0.036957  0.009544 -0.225991 -0.225775 -0.150331
# country  -0.134030 -0.080542 -0.056838 -0.264940 -0.263297 -0.227501
# budget   -0.100976 -0.527807 -0.755768  0.454715  0.433508  0.153750
# gross    -0.139046 -0.513700 -0.667839  0.392866  0.376774  0.307830
# ...

# %%
corr_mat = df_num.corr()
corr_pairs=corr_mat.unstack()

# %%
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.130598
#          genre      -0.011344
#          year       -0.089798
#          released   -0.087292
#                        ...
# runtime  country    -0.217617
#          budget      0.431627
#          gross       0.440904
#          company    -0.029611
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
df.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget        int64
# gross         int64
# company       int16
# runtime     float64
# dtype: object

# %%
corr_matrix= df.corr()
corr_pair= corr_matrix.unstack()

corr_pair
# Out:
# name     name        1.000000
#          rating     -0.029234
#          genre       0.010996
#          year        0.025542
#          released    0.025982
#                        ...
# runtime  country    -0.034477
#          budget      0.318695
#          gross       0.275796
#          company     0.037585
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs= corr_pairs.sort_values()

# %%
high_correlation= sorted_pairs[(sorted_pairs)>0.5]

# %%
high_correlation
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# released  year        0.961218
# year      released    0.961218
# budget    budget      1.000000
# genre     genre       1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# released  released    1.000000
# year      year        1.000000
# rating    rating      1.000000
# name      name        1.000000
# score     score       1.000000
# runtime   runtime     1.000000
# votes     votes       1.000000
# gross     gross       1.000000
# country   country     1.000000
# company   company     1.000000
# dtype: float64

# %%
# VOTES and BUDGET have the highest correlation to GROSS EARNINGS 

#CONCLUDED that Company has LOW correlation
